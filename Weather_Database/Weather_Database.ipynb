# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list. 
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f90a9a6a4d10f8dbb166b598dac8f769

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count. 
    record_count += 1

# Run an API request for each of the cities.
    try: 
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data_list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity, 
                          "Cloudiness": city_clouds, 
                          "Wind Speed": city_wind, 
                          "Country": city_country, 
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate the Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | marsabit
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | inta
# Processing Record 9 of Set 1 | bjorkelangen
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | flin flon
# Processing Record 13 of Set 1 | port-gentil
# Processing Record 14 of Set 1 | ixtapa
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | kirakira
# Processing Record 18 of Set 1 | miranda
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | kruisfontein
# Processing Record 24 of Set 1 | hastings
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | thai binh
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | irtyshskiy
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | nhulunbuy
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | gondar
# Processing Record 44 of Set 1 | rawson
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | planaltina
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | maubin
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | praia da vitoria
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | vallenar
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | waddan
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | mossoro
# Processing Record 12 of Set 2 | tautira
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | gorontalo
# Processing Record 18 of Set 2 | gazojak
# Processing Record 19 of Set 2 | kiama
# Processing Record 20 of Set 2 | yulara
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | dutlwe
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | anqing
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | torbay
# Processing Record 32 of Set 2 | nantucket
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | muros
# Processing Record 36 of Set 2 | qarqin
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 39 of Set 2 | yarada
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | biskamzha
# Processing Record 43 of Set 2 | palmer
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | teya
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | sijunjung
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | kavaratti
# Processing Record 50 of Set 2 | fountain
# Processing Record 1 of Set 3 | poum
# Processing Record 2 of Set 3 | ostersund
# Processing Record 3 of Set 3 | lishui
# Processing Record 4 of Set 3 | sola
# Processing Record 5 of Set 3 | gimli
# Processing Record 6 of Set 3 | qui nhon
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | kurush
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | taylorville
# Processing Record 11 of Set 3 | yauya
# Processing Record 12 of Set 3 | rusape
# Processing Record 13 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | hobart
# Processing Record 16 of Set 3 | el rosario
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | nandura
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | havoysund
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | januaria
# Processing Record 24 of Set 3 | lugus
# Processing Record 25 of Set 3 | harindanga
# Processing Record 26 of Set 3 | dunedin
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | narsaq
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | bonavista
# Processing Record 32 of Set 3 | bryan
# Processing Record 33 of Set 3 | itarema
# Processing Record 34 of Set 3 | tilichiki
# Processing Record 35 of Set 3 | puerto carreno
# Processing Record 36 of Set 3 | marawi
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | mount isa
# Processing Record 39 of Set 3 | rio gallegos
# Processing Record 40 of Set 3 | mitu
# Processing Record 41 of Set 3 | inhambane
# Processing Record 42 of Set 3 | krishnarajasagara
# Processing Record 43 of Set 3 | iisalmi
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | basco
# Processing Record 47 of Set 3 | san patricio
# Processing Record 48 of Set 3 | coahuayana
# Processing Record 49 of Set 3 | piripiri
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | sao francisco
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | oriximina
# Processing Record 4 of Set 4 | palmas
# Processing Record 5 of Set 4 | caceres
# Processing Record 6 of Set 4 | zeven
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | belyy yar
# Processing Record 9 of Set 4 | saint-augustin
# Processing Record 10 of Set 4 | dombasle-sur-meurthe
# Processing Record 11 of Set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 12 of Set 4 | broken hill
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | kango
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | papara
# Processing Record 18 of Set 4 | maku
# Processing Record 19 of Set 4 | arawa
# Processing Record 20 of Set 4 | ayacucho
# Processing Record 21 of Set 4 | monte azul
# Processing Record 22 of Set 4 | nikolo-pavlovskoye
# Processing Record 23 of Set 4 | vanimo
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | saint-louis
# Processing Record 26 of Set 4 | nome
# Processing Record 27 of Set 4 | tiarei
# Processing Record 28 of Set 4 | miraflores
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | bambanglipuro
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | yenagoa
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | umm lajj
# Processing Record 35 of Set 4 | daru
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | flinders
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | zhigansk
# Processing Record 40 of Set 4 | boa vista
# Processing Record 41 of Set 4 | ossora
# Processing Record 42 of Set 4 | klyuchi
# Processing Record 43 of Set 4 | reconquista
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | lethem
# Processing Record 46 of Set 4 | anzio
# Processing Record 47 of Set 4 | semey
# Processing Record 48 of Set 4 | esperance
# Processing Record 49 of Set 4 | hamamatsu
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | churintzio
# Processing Record 2 of Set 5 | khor
# Processing Record 3 of Set 5 | beringovskiy
# Processing Record 4 of Set 5 | mana
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | cabedelo
# Processing Record 9 of Set 5 | hun
# Processing Record 10 of Set 5 | ust-shonosha
# Processing Record 11 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 5 | chitral
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | geraldton
# Processing Record 16 of Set 5 | mocuba
# Processing Record 17 of Set 5 | tocantinopolis
# City not found. Skipping...
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | sai buri
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | maloy
# Processing Record 23 of Set 5 | luanda
# Processing Record 24 of Set 5 | ziro
# Processing Record 25 of Set 5 | haines junction
# Processing Record 26 of Set 5 | itapuranga
# Processing Record 27 of Set 5 | new norfolk
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | plettenberg bay
# Processing Record 30 of Set 5 | maceio
# Processing Record 31 of Set 5 | georgetown
# Processing Record 32 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 5 | oktyabrskiy
# Processing Record 34 of Set 5 | adrar
# Processing Record 35 of Set 5 | sibolga
# Processing Record 36 of Set 5 | vila franca do campo
# Processing Record 37 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 5 | dieppe
# Processing Record 39 of Set 5 | laguna
# Processing Record 40 of Set 5 | ahipara
# Processing Record 41 of Set 5 | port lincoln
# Processing Record 42 of Set 5 | castro
# Processing Record 43 of Set 5 | fez
# Processing Record 44 of Set 5 | biloela
# Processing Record 45 of Set 5 | pangkalanbuun
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 5 | nobeoka
# Processing Record 49 of Set 5 | honiara
# Processing Record 50 of Set 5 | magistralnyy
# Processing Record 1 of Set 6 | teahupoo
# Processing Record 2 of Set 6 | puerto ayora
# Processing Record 3 of Set 6 | banjar
# Processing Record 4 of Set 6 | sakakah
# Processing Record 5 of Set 6 | port hawkesbury
# Processing Record 6 of Set 6 | chengmai
# City not found. Skipping...
# Processing Record 7 of Set 6 | batagay-alyta
# Processing Record 8 of Set 6 | miyazu
# Processing Record 9 of Set 6 | pozhva
# Processing Record 10 of Set 6 | abu kamal
# Processing Record 11 of Set 6 | lynn haven
# Processing Record 12 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 6 | almaznyy
# Processing Record 14 of Set 6 | itapeva
# Processing Record 15 of Set 6 | taiyuan
# Processing Record 16 of Set 6 | tsumeb
# Processing Record 17 of Set 6 | kanina
# Processing Record 18 of Set 6 | tessalit
# Processing Record 19 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | mirabad
# Processing Record 22 of Set 6 | sri aman
# Processing Record 23 of Set 6 | nicosia
# Processing Record 24 of Set 6 | yar-sale
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | vanersborg
# Processing Record 27 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 28 of Set 6 | chumikan
# Processing Record 29 of Set 6 | nishihara
# Processing Record 30 of Set 6 | matara
# Processing Record 31 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 6 | tumut
# Processing Record 33 of Set 6 | iqaluit
# Processing Record 34 of Set 6 | lata
# Processing Record 35 of Set 6 | karla
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | oleksandrivka
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | vahan
# Processing Record 40 of Set 6 | kushima
# Processing Record 41 of Set 6 | mersing
# Processing Record 42 of Set 6 | amsterdam
# Processing Record 43 of Set 6 | sinnamary
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | pisco
# Processing Record 46 of Set 6 | fairbanks
# Processing Record 47 of Set 6 | mackay
# Processing Record 48 of Set 6 | hay river
# Processing Record 49 of Set 6 | bandarbeyla
# Processing Record 50 of Set 6 | ushtobe
# Processing Record 1 of Set 7 | vila
# Processing Record 2 of Set 7 | morgan city
# Processing Record 3 of Set 7 | mpika
# Processing Record 4 of Set 7 | mount gambier
# Processing Record 5 of Set 7 | klaksvik
# Processing Record 6 of Set 7 | brae
# Processing Record 7 of Set 7 | ornskoldsvik
# Processing Record 8 of Set 7 | san ramon
# Processing Record 9 of Set 7 | grand gaube
# Processing Record 10 of Set 7 | sisimiut
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | hamilton
# Processing Record 13 of Set 7 | half moon bay
# Processing Record 14 of Set 7 | sayyan
# Processing Record 15 of Set 7 | la palma
# Processing Record 16 of Set 7 | chabahar
# Processing Record 17 of Set 7 | bilibino
# Processing Record 18 of Set 7 | dharchula
# Processing Record 19 of Set 7 | panaba
# Processing Record 20 of Set 7 | seminole
# Processing Record 21 of Set 7 | coihaique
# Processing Record 22 of Set 7 | sunamganj
# City not found. Skipping...
# Processing Record 23 of Set 7 | alamos
# Processing Record 24 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | banda aceh
# Processing Record 27 of Set 7 | vila velha
# Processing Record 28 of Set 7 | asilah
# Processing Record 29 of Set 7 | forio
# Processing Record 30 of Set 7 | hasaki
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | san pedro
# Processing Record 34 of Set 7 | tighina
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | micheweni
# Processing Record 37 of Set 7 | los rastrojos
# Processing Record 38 of Set 7 | phonhong
# Processing Record 39 of Set 7 | dawson creek
# Processing Record 40 of Set 7 | hinton
# Processing Record 41 of Set 7 | east london
# Processing Record 42 of Set 7 | galesong
# Processing Record 43 of Set 7 | caluquembe
# Processing Record 44 of Set 7 | mitsamiouli
# Processing Record 45 of Set 7 | buford
# Processing Record 46 of Set 7 | quirinopolis
# Processing Record 47 of Set 7 | beyneu
# Processing Record 48 of Set 7 | keuruu
# Processing Record 49 of Set 7 | tecoanapa
# Processing Record 50 of Set 7 | yokadouma
# Processing Record 1 of Set 8 | ngunguru
# Processing Record 2 of Set 8 | jumla
# Processing Record 3 of Set 8 | ostrovnoy
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | kaeo
# Processing Record 6 of Set 8 | nalut
# Processing Record 7 of Set 8 | tanta
# Processing Record 8 of Set 8 | lamu
# Processing Record 9 of Set 8 | kadoma
# Processing Record 10 of Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 11 of Set 8 | ugoofaaru
# Processing Record 12 of Set 8 | presidencia roque saenz pena
# Processing Record 13 of Set 8 | gilgit
# Processing Record 14 of Set 8 | of
# City not found. Skipping...
# Processing Record 15 of Set 8 | saint-pierre
# Processing Record 16 of Set 8 | jining
# Processing Record 17 of Set 8 | pasighat
# Processing Record 18 of Set 8 | sorland
# Processing Record 19 of Set 8 | san quintin
# Processing Record 20 of Set 8 | maldonado
# Processing Record 21 of Set 8 | lazaro cardenas
# Processing Record 22 of Set 8 | mackenzie
# Processing Record 23 of Set 8 | takoradi
# Processing Record 24 of Set 8 | sioux lookout
# Processing Record 25 of Set 8 | jalu
# Processing Record 26 of Set 8 | evensk
# Processing Record 27 of Set 8 | blagoyevo
# Processing Record 28 of Set 8 | koumac
# Processing Record 29 of Set 8 | leh
# Processing Record 30 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 8 | madang
# Processing Record 32 of Set 8 | aswan
# Processing Record 33 of Set 8 | manchester
# Processing Record 34 of Set 8 | kanniyakumari
# Processing Record 35 of Set 8 | peniche
# Processing Record 36 of Set 8 | pozo colorado
# Processing Record 37 of Set 8 | minab
# Processing Record 38 of Set 8 | roma
# Processing Record 39 of Set 8 | pechora
# Processing Record 40 of Set 8 | tigil
# Processing Record 41 of Set 8 | chiredzi
# Processing Record 42 of Set 8 | tual
# Processing Record 43 of Set 8 | ramasukha
# City not found. Skipping...
# Processing Record 44 of Set 8 | kapelle
# Processing Record 45 of Set 8 | balkanabat
# Processing Record 46 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 8 | eberswalde
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | zhuhai
# Processing Record 50 of Set 8 | taybad
# Processing Record 1 of Set 9 | igarka
# Processing Record 2 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 9 | lompoc
# Processing Record 4 of Set 9 | samandag
# Processing Record 5 of Set 9 | abalak
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | havelock
# Processing Record 8 of Set 9 | thompson
# Processing Record 9 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 9 | shubarkuduk
# Processing Record 11 of Set 9 | robertsport
# Processing Record 12 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 9 | manzil kamil
# Processing Record 14 of Set 9 | san juan
# Processing Record 15 of Set 9 | shihezi
# Processing Record 16 of Set 9 | bahia blanca
# Processing Record 17 of Set 9 | zwedru
# Processing Record 18 of Set 9 | broome
# Processing Record 19 of Set 9 | macia
# Processing Record 20 of Set 9 | eten
# Processing Record 21 of Set 9 | atherton
# Processing Record 22 of Set 9 | tongren
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | san antero
# Processing Record 25 of Set 9 | kysyl-syr
# Processing Record 26 of Set 9 | simao
# Processing Record 27 of Set 9 | ales
# Processing Record 28 of Set 9 | grindavik
# Processing Record 29 of Set 9 | vostok
# Processing Record 30 of Set 9 | yushan
# Processing Record 31 of Set 9 | hammerfest
# Processing Record 32 of Set 9 | launceston
# Processing Record 33 of Set 9 | kuttanallur
# City not found. Skipping...
# Processing Record 34 of Set 9 | acapulco
# Processing Record 35 of Set 9 | murgab
# Processing Record 36 of Set 9 | kudahuvadhoo
# Processing Record 37 of Set 9 | port moresby
# Processing Record 38 of Set 9 | touros
# Processing Record 39 of Set 9 | lopatinskiy
# Processing Record 40 of Set 9 | urumqi
# Processing Record 41 of Set 9 | exu
# Processing Record 42 of Set 9 | rancho palos verdes
# Processing Record 43 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 9 | surin
# Processing Record 45 of Set 9 | puerto quijarro
# Processing Record 46 of Set 9 | fukue
# Processing Record 47 of Set 9 | taoudenni
# Processing Record 48 of Set 9 | tiznit
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | yamada
# Processing Record 1 of Set 10 | nanchang
# Processing Record 2 of Set 10 | catuday
# Processing Record 3 of Set 10 | seoul
# Processing Record 4 of Set 10 | vila do maio
# Processing Record 5 of Set 10 | hami
# Processing Record 6 of Set 10 | tateyama
# Processing Record 7 of Set 10 | hambantota
# Processing Record 8 of Set 10 | ilhabela
# Processing Record 9 of Set 10 | laureles
# Processing Record 10 of Set 10 | arroio dos ratos
# Processing Record 11 of Set 10 | yurimaguas
# Processing Record 12 of Set 10 | buenos aires
# Processing Record 13 of Set 10 | bud
# Processing Record 14 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 10 | groa
# Processing Record 16 of Set 10 | samarai
# Processing Record 17 of Set 10 | krivopolyanye
# City not found. Skipping...
# Processing Record 18 of Set 10 | ayan
# Processing Record 19 of Set 10 | nouadhibou
# Processing Record 20 of Set 10 | teknaf
# Processing Record 21 of Set 10 | galle
# Processing Record 22 of Set 10 | rantepao
# Processing Record 23 of Set 10 | bathsheba
# Processing Record 24 of Set 10 | kaarina
# Processing Record 25 of Set 10 | ternovka
# Processing Record 26 of Set 10 | jinhua
# Processing Record 27 of Set 10 | santo tomas
# Processing Record 28 of Set 10 | kuala terengganu
# Processing Record 29 of Set 10 | jalpa
# Processing Record 30 of Set 10 | kerrobert
# Processing Record 31 of Set 10 | balagansk
# Processing Record 32 of Set 10 | arman
# Processing Record 33 of Set 10 | talcahuano
# Processing Record 34 of Set 10 | digoin
# Processing Record 35 of Set 10 | nelson bay
# Processing Record 36 of Set 10 | opuwo
# Processing Record 37 of Set 10 | gerede
# Processing Record 38 of Set 10 | mehamn
# Processing Record 39 of Set 10 | dvinskoy
# Processing Record 40 of Set 10 | marzuq
# Processing Record 41 of Set 10 | makakilo city
# Processing Record 42 of Set 10 | chiali
# City not found. Skipping...
# Processing Record 43 of Set 10 | the pas
# Processing Record 44 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 10 | paris
# Processing Record 46 of Set 10 | santa vitoria do palmar
# Processing Record 47 of Set 10 | college
# Processing Record 48 of Set 10 | santa maria
# Processing Record 49 of Set 10 | cidreira
# Processing Record 50 of Set 10 | east hemet
# Processing Record 1 of Set 11 | unai
# Processing Record 2 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 3 of Set 11 | toguchin
# Processing Record 4 of Set 11 | inuvik
# Processing Record 5 of Set 11 | sitka
# Processing Record 6 of Set 11 | lyuban
# Processing Record 7 of Set 11 | gambela
# Processing Record 8 of Set 11 | warrnambool
# Processing Record 9 of Set 11 | rawicz
# Processing Record 10 of Set 11 | pravia
# Processing Record 11 of Set 11 | maxixe
# Processing Record 12 of Set 11 | samarinda
# Processing Record 13 of Set 11 | ziarat
# Processing Record 14 of Set 11 | sao gabriel da cachoeira
# Processing Record 15 of Set 11 | camopi
# Processing Record 16 of Set 11 | tammisaari
# Processing Record 17 of Set 11 | freeport
# Processing Record 18 of Set 11 | wana
# Processing Record 19 of Set 11 | akonolinga
# Processing Record 20 of Set 11 | shanghai
# Processing Record 21 of Set 11 | faanui
# Processing Record 22 of Set 11 | bubaque
# Processing Record 23 of Set 11 | iskateley
# Processing Record 24 of Set 11 | yavaros
# Processing Record 25 of Set 11 | kharp
# Processing Record 26 of Set 11 | sao lourenco
# Processing Record 27 of Set 11 | maues
# Processing Record 28 of Set 11 | kostomuksha
# Processing Record 29 of Set 11 | zabol
# Processing Record 30 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 11 | bulawayo
# Processing Record 32 of Set 11 | vohibinany
# Processing Record 33 of Set 11 | santa rosa
# Processing Record 34 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 11 | upernavik
# Processing Record 36 of Set 11 | nirasaki
# Processing Record 37 of Set 11 | karakol
# Processing Record 38 of Set 11 | juneau
# Processing Record 39 of Set 11 | abu samrah
# Processing Record 40 of Set 11 | quevedo
# Processing Record 41 of Set 11 | meadow lake
# Processing Record 42 of Set 11 | salmas
# Processing Record 43 of Set 11 | varnavino
# Processing Record 44 of Set 11 | chateauroux
# Processing Record 45 of Set 11 | berlevag
# Processing Record 46 of Set 11 | okahandja
# Processing Record 47 of Set 11 | egvekinot
# Processing Record 48 of Set 11 | bilma
# Processing Record 49 of Set 11 | dillon
# Processing Record 50 of Set 11 | bacong
# Processing Record 1 of Set 12 | aksarka
# Processing Record 2 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 3 of Set 12 | muroto
# Processing Record 4 of Set 12 | avera
# Processing Record 5 of Set 12 | umm kaddadah
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | sasd
# Processing Record 8 of Set 12 | hovd
# Processing Record 9 of Set 12 | lubana
# Processing Record 10 of Set 12 | kalaikunda
# Processing Record 11 of Set 12 | eyl
# Processing Record 12 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | muzhi
# Processing Record 14 of Set 12 | pinega
# Processing Record 15 of Set 12 | morehead
# Processing Record 16 of Set 12 | strezhevoy
# Processing Record 17 of Set 12 | korla
# Processing Record 18 of Set 12 | tutoia
# Processing Record 19 of Set 12 | isangel
# Processing Record 20 of Set 12 | palmerston
# Processing Record 21 of Set 12 | cururupu
# Processing Record 22 of Set 12 | nara
# Processing Record 23 of Set 12 | ust-ishim
# Processing Record 24 of Set 12 | lima
# Processing Record 25 of Set 12 | belmonte
# Processing Record 26 of Set 12 | magadan
# Processing Record 27 of Set 12 | kanganpur
# Processing Record 28 of Set 12 | madinat sittah uktubar
# Processing Record 29 of Set 12 | lensk
# Processing Record 30 of Set 12 | moerai
# Processing Record 31 of Set 12 | port hedland
# Processing Record 32 of Set 12 | constitucion
# Processing Record 33 of Set 12 | fort nelson
# Processing Record 34 of Set 12 | comodoro rivadavia
# Processing Record 35 of Set 12 | lakes entrance
# Processing Record 36 of Set 12 | arlit
# Processing Record 37 of Set 12 | rancho veloz
# Processing Record 38 of Set 12 | volot
# Processing Record 39 of Set 12 | solnechnyy
# Processing Record 40 of Set 12 | aklavik
# Processing Record 41 of Set 12 | mezen
# Processing Record 42 of Set 12 | sahuaripa
# Processing Record 43 of Set 12 | kuching
# Processing Record 44 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 45 of Set 12 | thinadhoo
# Processing Record 46 of Set 12 | atar
# Processing Record 47 of Set 12 | cacapava do sul
# Processing Record 48 of Set 12 | biak
# Processing Record 49 of Set 12 | aktau
# Processing Record 50 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | lubango
# Processing Record 2 of Set 13 | poya
# Processing Record 3 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 13 | san antonio
# Processing Record 6 of Set 13 | northam
# Processing Record 7 of Set 13 | amarpur
# Processing Record 8 of Set 13 | santa marta
# Processing Record 9 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 13 | aitape
# Processing Record 11 of Set 13 | abonnema
# Processing Record 12 of Set 13 | bara
# Processing Record 13 of Set 13 | tarko-sale
# Processing Record 14 of Set 13 | kenai
# Processing Record 15 of Set 13 | davila
# Processing Record 16 of Set 13 | camacari
# Processing Record 17 of Set 13 | esmeraldas
# Processing Record 18 of Set 13 | kamiiso
# Processing Record 19 of Set 13 | benguela
# Processing Record 20 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 13 | krasnousolskiy
# City not found. Skipping...
# Processing Record 22 of Set 13 | melnikovo
# Processing Record 23 of Set 13 | mizdah
# Processing Record 24 of Set 13 | sambava
# Processing Record 25 of Set 13 | baoro
# Processing Record 26 of Set 13 | coffs harbour
# Processing Record 27 of Set 13 | tuatapere
# Processing Record 28 of Set 13 | mareeba
# Processing Record 29 of Set 13 | nadym
# Processing Record 30 of Set 13 | luwuk
# Processing Record 31 of Set 13 | bira
# Processing Record 32 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 13 | waipawa
# Processing Record 34 of Set 13 | devonport
# Processing Record 35 of Set 13 | kismayo
# Processing Record 36 of Set 13 | manaure
# Processing Record 37 of Set 13 | codrington
# Processing Record 38 of Set 13 | padang
# Processing Record 39 of Set 13 | gourcy
# Processing Record 40 of Set 13 | asau
# Processing Record 41 of Set 13 | zhezkazgan
# Processing Record 42 of Set 13 | manavalakurichi
# Processing Record 43 of Set 13 | khorramshahr
# Processing Record 44 of Set 13 | angoram
# Processing Record 45 of Set 13 | oktyabrskoye
# Processing Record 46 of Set 13 | melilla
# Processing Record 47 of Set 13 | labuhan
# Processing Record 48 of Set 13 | pavilosta
# Processing Record 49 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 13 | lieksa
# Processing Record 1 of Set 14 | katangli
# Processing Record 2 of Set 14 | moroni
# Processing Record 3 of Set 14 | qandala
# Processing Record 4 of Set 14 | camacha
# Processing Record 5 of Set 14 | johnstown
# Processing Record 6 of Set 14 | doha
# Processing Record 7 of Set 14 | yambio
# Processing Record 8 of Set 14 | oranjemund
# Processing Record 9 of Set 14 | lichuan
# Processing Record 10 of Set 14 | tabora
# Processing Record 11 of Set 14 | bam
# Processing Record 12 of Set 14 | eirunepe
# Processing Record 13 of Set 14 | seabra
# Processing Record 14 of Set 14 | rocha
# Processing Record 15 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 14 | buala
# Processing Record 17 of Set 14 | tromso
# Processing Record 18 of Set 14 | kununurra
# Processing Record 19 of Set 14 | kushiro
# Processing Record 20 of Set 14 | andenes
# Processing Record 21 of Set 14 | wajir
# Processing Record 22 of Set 14 | tura
# Processing Record 23 of Set 14 | mnogovershinnyy
# Processing Record 24 of Set 14 | alenquer
# Processing Record 25 of Set 14 | saint-francois
# Processing Record 26 of Set 14 | belaya gora
# Processing Record 27 of Set 14 | pyshma
# Processing Record 28 of Set 14 | verkhnyaya pyshma
# Processing Record 29 of Set 14 | tabas
# Processing Record 30 of Set 14 | baherden
# Processing Record 31 of Set 14 | mananjary
# Processing Record 32 of Set 14 | chingirlau
# Processing Record 33 of Set 14 | niquero
# Processing Record 34 of Set 14 | rosetta
# Processing Record 35 of Set 14 | shenjiamen
# Processing Record 36 of Set 14 | carutapera
# Processing Record 37 of Set 14 | sesheke
# Processing Record 38 of Set 14 | nueva concepcion
# Processing Record 39 of Set 14 | redlands
# Processing Record 40 of Set 14 | guarapari
# Processing Record 41 of Set 14 | nacala
# Processing Record 42 of Set 14 | itaituba
# Processing Record 43 of Set 14 | hayrabolu
# Processing Record 44 of Set 14 | gat
# Processing Record 45 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 46 of Set 14 | harboore
# Processing Record 47 of Set 14 | alofi
# Processing Record 48 of Set 14 | kuusamo
# Processing Record 49 of Set 14 | peikang
# City not found. Skipping...
# Processing Record 50 of Set 14 | kibala
# Processing Record 1 of Set 15 | bairiki
# Processing Record 2 of Set 15 | ulaanbaatar
# Processing Record 3 of Set 15 | faya
# Processing Record 4 of Set 15 | betanzos
# Processing Record 5 of Set 15 | la rioja
# Processing Record 6 of Set 15 | todos santos
# Processing Record 7 of Set 15 | caraballeda
# Processing Record 8 of Set 15 | larsnes
# Processing Record 9 of Set 15 | thaton
# Processing Record 10 of Set 15 | yeniseysk
# Processing Record 11 of Set 15 | lucea
# Processing Record 12 of Set 15 | viedma
# Processing Record 13 of Set 15 | dwarahat
# Processing Record 14 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 15 | alpinopolis
# Processing Record 16 of Set 15 | san rafael
# Processing Record 17 of Set 15 | cockburn town
# Processing Record 18 of Set 15 | adre
# Processing Record 19 of Set 15 | vao
# Processing Record 20 of Set 15 | manaira
# Processing Record 21 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 22 of Set 15 | ryotsu
# Processing Record 23 of Set 15 | atlantic city
# Processing Record 24 of Set 15 | ulladulla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 661

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     78.17        76          13
# 1          Dikson  73.5069   80.5464    -23.39       100          30
# 2  Ribeira Grande  38.5167  -28.7000     62.60        72          40
# 3         Mataura -46.1927  168.8643     53.01        97         100
# 4        Marsabit   2.3284   37.9899     75.74        39         100
# 5   Mar Del Plata -38.0023  -57.5575     68.00        77          90
# 6            Inta  66.0317   60.1659      1.96        99          32
# 7    Bjorkelangen  59.8848   11.5694     41.00        95          85
# 8       Jamestown  42.0970  -79.2353     53.60       100          90
# 9       Flin Flon  54.7682 -101.8650     23.00        50          90
#
#    Wind Speed Country Current Description
# 0       16.73      PF          light rain
# 1        6.78      RU    scattered clouds
# 2       13.80      PT    scattered clouds
# 3        2.68      NZ     overcast clouds
# 4       12.35      KE     overcast clouds
# 5       13.80      AR          light rain
# 6        5.17      RU    scattered clouds
# 7        5.99      NO          light rain
# 8        4.09      US          light rain
# 9        6.91      CA     overcast clouds

# %%
# Reorder columns in city_data_df DataFrame.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     78.17        76          13
# 1          Dikson      RU  73.5069   80.5464    -23.39       100          30
# 2  Ribeira Grande      PT  38.5167  -28.7000     62.60        72          40
# 3         Mataura      NZ -46.1927  168.8643     53.01        97         100
# 4        Marsabit      KE   2.3284   37.9899     75.74        39         100
# 5   Mar Del Plata      AR -38.0023  -57.5575     68.00        77          90
# 6            Inta      RU  66.0317   60.1659      1.96        99          32
# 7    Bjorkelangen      NO  59.8848   11.5694     41.00        95          85
# 8       Jamestown      US  42.0970  -79.2353     53.60       100          90
# 9       Flin Flon      CA  54.7682 -101.8650     23.00        50          90
#
#    Wind Speed Current Description
# 0       16.73          light rain
# 1        6.78    scattered clouds
# 2       13.80    scattered clouds
# 3        2.68     overcast clouds
# 4       12.35     overcast clouds
# 5       13.80          light rain
# 6        5.17    scattered clouds
# 7        5.99          light rain
# 8        4.09          light rain
# 9        6.91     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
